# %%
import tensorflow as tf

X=tf.range(10)
# Out:
# C:\Users\keonhi\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\keonhi\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\keonhi\anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
X
# Out:
# <tf.Tensor 'range:0' shape=(10,) dtype=int32>

# %%
dataset =tf.data.Dataset.from_tensor_slices(X)

# %%
dataset
# Out:
# <DatasetV1Adapter shapes: (), types: tf.int32>

# %%
for item in dataset:
    print(item)
# Out:
# Tensor("IteratorGetNext:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_1:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_2:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_3:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_4:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_5:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_6:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_7:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_8:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_9:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_10:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_11:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_12:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_13:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_14:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_15:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_16:0", shape=(), dtype=int32)
# Tensor("IteratorGetNext_17:0", shape=(), dtype=int32)
# ...
